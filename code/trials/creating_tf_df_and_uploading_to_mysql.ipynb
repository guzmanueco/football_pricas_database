# %%
# %run -i ../scrapping_functions.py
# %run -i ../settings.py

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

 
db = pymysql.connect(host = host,user = user,password = password,port = port)  
cursor = db.cursor()
cursor.execute('USE football_prices_project')
# Out:
# 0

# %%
# variables for extractions
headers_tf = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
url_tf = "https://www.transfermarkt.co.uk/transfers/transferrekorde/statistik/top/plus/0/galerie/0?saison_id=2019"

# %%
urlSoup = getAndParseURL(url_tf, headers_tf)

# %%
playersNames = gettingPlayersNames(urlSoup)
playersPos = gettingPlayersPositions(urlSoup)
playersValue = gettingPlayersValue(urlSoup)

# %%
df = pd.DataFrame({'Name':playersNames, 'Position':playersPos, 'Value(million_pounds)':playersValue})

# %%
df
# Out:
#                  Name            Position Value(million_pounds)
# 0          João Félix      Second Striker              £113.40m
# 1   Antoine Griezmann      Second Striker              £108.00m
# 2         Eden Hazard         Left Winger              £103.50m
# 3       Harry Maguire         Centre-Back               £78.30m
# 4    Matthijs de Ligt         Centre-Back               £76.95m
# 5     Lucas Hernández         Centre-Back               £72.00m
# 6        Nicolas Pépé        Right Winger               £72.00m
# 7     Frenkie de Jong    Central Midfield               £67.50m
# 8               Rodri  Defensive Midfield               £63.00m
# 9       Romelu Lukaku      Centre-Forward               £58.50m
# 10       João Cancelo          Right-Back               £58.50m
# 11    Tanguy Ndombélé    Central Midfield               £54.00m
# 12         Luka Jovic      Centre-Forward               £54.00m
# 13    Bruno Fernandes  Attacking Midfield               £49.50m
# ...
